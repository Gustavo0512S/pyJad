# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong><br/><br/><br/><br/>
#         Funções
#     </strong>
# </p>

# %%
# Simples

# sempre com def

# %%
# Com retorno

# def com função return  - tras o que sua função faz de fato pra ser util dentro do relatorio

# %%
# Com parâmetros e argumentos

def dizoi(nome):
    return(f'Oi, {nome}')

def soma2valores(num1, num2):
    return num1 + num2

# dizoi(input())

soma2valores(num1=15, num2=30)
soma2valores(15,30)
# Out:
# 45

# %%
def gerardesconto(valor, desconto = 0.1):

    """ Função calcula um desconto por % inserido
        Vaalor pode ser float ou int
        desconto: precisa ser informato

    """
    return valor * desconto

gerardesconto(100,4.8)
# Out:
# 480.0

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong><br/><br/><br/><br/>
#         Bibliotecas
#     </strong>
# </p>

# %%
import time
from random import randint

print('Gugão')
time.sleep(2)
print('Gugão')
# Out:
# Gugão
# Gugão

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong>
#         Instalando bibliotecas
#     </strong>
# </p>

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong></br></br></br></br>
#         DATETIME
#     </strong>
# </p>

# %%
import datetime
from datetime import datetime

datetime.today()

import locale
locale.setlocale(locale.LC_TIME, 'pt_BR.UTF-8')
locale.setlocale(locale.LC_TIME, 'portuguese')

datetime.today()
hoje = datetime.now(strftime(" %d/%m/%y, %H:%S "))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       8 locale.setlocale(locale.LC_TIME, 'portuguese')
#      10 datetime.today()
# ---> 11 hoje = datetime.now(strftime(" %d/%m/%y, %H:%S "))
#
# NameError: name 'strftime' is not defined

# %%
import locale
locale.setlocale(locale.LC_TIME, 'pt_BR.UTF-8')
locale.setlocale(locale.LC_TIME, 'portuguese')

datetime.today()
hoje = datetime.now(strftime(" %d/%m/%y, %H:%S "))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 locale.setlocale(locale.LC_TIME, 'pt_BR.UTF-8')
#       3 locale.setlocale(locale.LC_TIME, 'portuguese')
# ----> 5 datetime.today()
#       6 hoje = datetime.now(strftime("%d/%m/%y, %H:%S"))
#
# NameError: name 'datetime' is not defined

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong></br></br></br></br>
#         Criando arquivos com python
#     </strong>
# </p>

# %%
with open('teste.txt', mode='a', encoding='UTF8') as arquivo:  # Open é bom só pra TXT (MODE = 'A' continua mode = 'w' substitui)
         arquivo.write("marta\n".title())

# %%
with open('teste.txt', encoding='UTF8') as arquivo:
    # arquivo.read()
    daods = arquivo.readlines()

for linha in daods:
    print(linha.replace('\n',''))
# Out:
# gu
# gu
# gu
# gu
# gu
# Gu
# Marta

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong>
#         lendo arquivos com python
#     </strong>
# </p>

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong></br></br></br></br>
#         JSON
#     </strong>
# </p>

# %%
import json


try:
    with open(r'dados\contas.json', 'r', encoding='UTF8') as arquivo2:
        contas = json.load(arquivo2)

except FileNotFoundError as e:
    print(e)

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong><br/><br/><br/><br/>
#         Tratamento
#     </strong>
# </p>

# %%
# Converter data em texto para data real (datetime)

from datetime import datetime

for conta in contas:
    conta['vencimento'] = datetime.strptime(conta['vencimento'],'%d/%m/%Y')


# vencimento = [datetime.strftime(item['vencimento'], '%d/%m/%Y' ) for item in contas]
# for data in vencimento:
#     print(data)
#     print(type(data))

# %%
# Verificando conversão

contas[0],['vencimento']
print(vencimento)
# Out:
# [datetime.datetime(2026, 1, 27, 0, 0), datetime.datetime(2026, 1, 8, 0, 0), datetime.datetime(2026, 1, 24, 0, 0), datetime.datetime(2026, 1, 5, 0, 0), datetime.datetime(2026, 1, 14, 0, 0), datetime.datetime(2026, 1, 24, 0, 0), datetime.datetime(2026, 1, 12, 0, 0), datetime.datetime(2026, 1, 15, 0, 0), datetime.datetime(2026, 1, 10, 0, 0), datetime.datetime(2026, 1, 10, 0, 0), datetime.datetime(2026, 1, 25, 0, 0), datetime.datetime(2026, 1, 2, 0, 0), datetime.datetime(2026, 1, 21, 0, 0), datetime.datetime(2026, 1, 12, 0, 0), datetime.datetime(2026, 1, 22, 0, 0), datetime.datetime(2026, 1, 6, 0, 0), datetime.datetime(2026, 1, 22, 0, 0), datetime.datetime(2026, 1, 4, 0, 0), datetime.datetime(2026, 1, 25, 0, 0), datetime.datetime(2026, 1, 20, 0, 0), datetime.datetime(2026, 1, 17, 0, 0), datetime.datetime(2026, 1, 1, 0, 0), datetime.datetime(2026, 1, 14, 0, 0), datetime.datetime(2026, 1, 19, 0, 0), datetime.datetime(2026, 1, 6, 0, 0), datetime.datetime(2026, 1, 28, 0, 0), datetime.datetime(2026, 1, 22, 0, 0), datetime.datetime(2026, 1, 6, 0, 0), datetime.datetime(2026, 1, 14, 0, 0), datetime.datetime(2026, 1, 3, 0, 0), datetime.datetime(2026, 1, 27, 0, 0), datetime.datetime(2026, 1, 15, 0, 0), datetime.datetime(2026, 1, 20, 0, 0), datetime.datetime(2026, 1, 1, 0, 0), datetime.datetime(2026, 1, 25, 0, 0), datetime.datetime(2026, 1, 16, 0, 0), datetime.datetime(2026, 1, 23, 0, 0), datetime.datetime(2026, 1, 7, 0, 0), datetime.datetime(2026, 1, 5, 0, 0), datetime.datetime(2026, 1, 16, 0, 0), datetime.datetime(2026, 1, 24, 0, 0), datetime.datetime(2026, 1, 13, 0, 0), datetime.datetime(2026, 1, 27, 0, 0), datetime.datetime(2026, 1, 15, 0, 0), datetime.datetime(2026, 1, 3, 0, 0), datetime.datetime(2026, 1, 27, 0, 0), datetime.datetime(2026, 1, 25, 0, 0), datetime.datetime(2026, 1, 20, 0, 0), datetime.datetime(2026, 1, 26, 0, 0), datetime.datetime(2026, 1, 28, 0, 0), datetime.datetime(2026, 1, 3, 0, 0), datetime.datetime(2026, 1, 9, 0, 0), datetime.datetime(2026, 1, 12, 0, 0), datetime.datetime(2026, 1, 17, 0, 0), datetime.datetime(2026, 1, 3, 0, 0), datetime.datetime(2026, 1, 4, 0, 0), datetime.datetime(2026, 1, 22, 0, 0), datetime.datetime(2026, 1, 12, 0, 0), datetime.datetime(2026, 1, 2, 0, 0), datetime.datetime(2026, 1, 19, 0, 0), datetime.datetime(2026, 1, 4, 0, 0), datetime.datetime(2026, 1, 7, 0, 0), datetime.datetime(2026, 1, 2, 0, 0), datetime.datetime(2026, 1, 7, 0, 0), datetime.datetime(2026, 1, 28, 0, 0), datetime.datetime(2026, 1, 27, 0, 0), datetime.datetime(2026, 1, 14, 0, 0), datetime.datetime(2026, 1, 23, 0, 0), datetime.datetime(2026, 1, 1, 0, 0), datetime.datetime(2026, 1, 2, 0, 0), datetime.datetime(2026, 1, 10, 0, 0), datetime.datetime(2026, 1, 16, 0, 0), datetime.datetime(2026, 1, 12, 0, 0), datetime.datetime(2026, 1, 11, 0, 0), datetime.datetime(2026, 1, 6, 0, 0), datetime.datetime(2026, 1, 28, 0, 0), datetime.datetime(2026, 1, 24, 0, 0), datetime.datetime(2026, 1, 8, 0, 0), datetime.datetime(2026, 1, 12, 0, 0), datetime.datetime(2026, 1, 27, 0, 0), datetime.datetime(2026, 1, 19, 0, 0), datetime.datetime(2026, 1, 4, 0, 0), datetime.datetime(2026, 1, 2, 0, 0), datetime.datetime(2026, 1, 13, 0, 0), datetime.datetime(2026, 1, 6, 0, 0), datetime.datetime(2026, 1, 4, 0, 0), datetime.datetime(2026, 1, 10, 0, 0), datetime.datetime(2026, 1, 8, 0, 0), datetime.datetime(2026, 1, 16, 0, 0), datetime.datetime(2026, 1, 23, 0, 0), datetime.datetime(2026, 1, 14, 0, 0), datetime.datetime(2026, 1, 20, 0, 0), datetime.datetime(2026, 1, 20, 0, 0), datetime.datetime(2026, 1, 25, 0, 0), datetime.datetime(2026, 1, 6, 0, 0), datetime.datetime(2026, 1, 23, 0, 0), datetime.datetime(2026, 1, 8, 0, 0), datetime.datetime(2026, 1, 18, 0, 0), datetime.datetime(2026, 1, 14, 0, 0), datetime.datetime(2026, 1, 25, 0, 0), datetime.datetime(2026, 1, 21, 0, 0), datetime.datetime(2026, 1, 12, 0, 0), datetime.datetime(2026, 1, 13, 0, 0), datetime.datetime(2026, 1, 5, 0, 0), datetime.datetime(2026, 1, 9, 0, 0), datetime.datetime(2026, 1, 24, 0, 0), dateti ...

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong><br/><br/><br/><br/>
#         Análise (Vencimentos)
#     </strong>
# </p>

# %%
# Quantas contas estão vencidas?

from datetime import datetime

hoje = datetime.today()
contas_vencidas = []

for conta in contas:
    if conta['vencimento'] < hoje and conta['status'] == 'Em aberto' and conta['tipo'] =="Pagar":
        contas_vencidas.append(conta)

len(contas_vencidas)
# Out:
# 777

# %%
# Total em contas vencidas?

total_vencido = 0

for conta in contas_vencidas:
    total_vencido += conta['valor']

round(total_vencido, 2)
# Out:
# 1965984.26

# %% [markdown]
# <p style="font-size: 1.1rem; color:#9beb3b; text-align: center; font-family: monospace ">
#     <strong><br/><br/><br/><br/>
#         Análise (pagar e receber)
#     </strong>
# </p>

# %%
# Quantas contas temos neste arquivo


# Acessando campo valor


# Acessandos todos os valores das 5 primeiras contas

# %%
# Separando contas a pagar e receber
